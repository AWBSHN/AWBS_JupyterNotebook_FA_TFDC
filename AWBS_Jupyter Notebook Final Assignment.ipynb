# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ***
# **Aurora Waleska Borjas Sosa**
# Occupation: Business Analyst

# %% [markdown]
# *Im interested in Data Science because I want improve my job opportunities; we live in a data driven world and turning data into value is the key.
# I want to keep helping organizations to make better business decisions.*

# %% [markdown]
# ### In the next cell I divide 3/5

# %%
3/5
# Out:
# 0.6

# %% [markdown]
# ***
# #### **Bulleted list**
#
# *Open Source Tools*
# - Data Management:
#   * SQL
#   * NoSQL
#   * File-Based
#
# #### **Numbered list**
#
# *Open Source Tools*
#
# Data Management:
# 1. SQL
#     1. MySQL
#     2. PostgreSQL
# 1. NoSQL
#     3. Mongo DB
#     4. CouchDB
#     5. Cassandra
# 45. File-Based
#
# #### **Table**
#
# *Top sights in Honduras:*
#
# |Sight|Deparment|Interest
# |-----|-----|-----|
# |Utila|Islas de la Bahía|Beaches
# |Ruinas de Copán|Copán|History
# |Punta Sal|Atlántida|Natural Reserve
# |Cayos Cochinos| Islas de la Bahía|Beaches
# |Comayagua|Comayagua|Art and Culture
#
#
# #### **Hyperlink**
#
#
# [**Utila, el mejor sitio de Honduras para nadar con el Tiburón Ballena**](https://hondurasisgreat.org/utila-el-mejor-sitio-de-honduras-para-nadar-con-el-tiburon-ballena/)
#
# ![Utila_Honduras.gif](attachment:275dbf73-fd4c-4bf2-a657-e1169fc2eac6.gif)
